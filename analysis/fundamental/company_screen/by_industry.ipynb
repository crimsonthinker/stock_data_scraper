# %%
ROOT_PATH = 'C:/Users/khoan/OneDrive/Documents/stock_data_scraper'
import os
os.chdir(ROOT_PATH)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.generic_utils import SQLModule
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
engine = SQLModule.get_engine(country = 'australia')

# %%
# Collect from 'company_section.ipynb'
SECTOR = 'Consumer Defensive'
INDUSTRY = 'Farm Products'

# %%
# Get distribution of metrics of company within the industry
query = f"""
    SELECT
        company_name,
        stock_code,
        fundamental,
        fundamental->>'industry' AS industry,
        fundamental->>'marketCap' AS market_cap,
        fundamental->>'priceToBook' AS pb_ratio,
        fundamental->>'profitMargins' AS profit_margins,
        fundamental->>'trailingEps' AS earning_per_share,
        fundamental->>'enterpriseToEbitda' AS evebitda,
        fundamental->>'trailingPegRatio' AS peg_ratio,
        fundamental->>'debtToEquity' AS de_ratio
    FROM stock_info
    WHERE
        fundamental->>'sector' = '{SECTOR}'
        AND
        fundamental->>'industry' = '{INDUSTRY}'
"""
df = pd.read_sql_query(query, engine)
df
# Out:
#                            company_name stock_code  \
# 0   Australian Agricultural Company Ltd        AAC
# 1            Duxton Broadacre Farms Ltd        DBF
# 2                Clean Seas Seafood Ltd        CSS
# 3                  Farm Pride Foods Ltd        FRM
# 4              Murray Cod Australia Ltd        MCA
# 5        New Zealand King Salmon Co Ltd        NZK
# 6              Rare Foods Australia Ltd        RFA
# 7                      Silver Mines Ltd        SVL
# 8              Australian Agri Projects        AAP
# 9                           East 33 Ltd        E33
# 10                           Elders Ltd        ELD
# 11                    Inghams Group Ltd        ING
# 12                        Graincorp Ltd        GNC
# 13        Namoi Cotton Co-Operative Ltd        NAM
# 14             Lynch Group Holdings Ltd        LGL
# 15                   Seafarms Group Ltd        SFG
# 16                  Ricegrowers Limited      SGLLV
# ...

# %%
# Distribution of market cap
fig = go.Figure()
fig.add_trace(
    go.Histogram(x = df['market_cap'].apply(lambda x : int(x)))
)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')
fig.update_xaxes(title = f'Market capital of company in sector "{SECTOR}" and industry "{INDUSTRY}"')
fig.update_layout(
    width = 1000,
    height = 500,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 20)
)
fig.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Distribution of market cap
fig = go.Figure()
fig.add_trace(
    go.Histogram(x = df['pb_ratio'].apply(lambda x : float(x) if not pd.isna(x) else None))
)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')
fig.update_xaxes(title = f'P/B ratio of company in sector "{SECTOR}" and industry "{INDUSTRY}"')
fig.update_layout(
    width = 1000,
    height = 500,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 20)
)
fig.show()

# %%
# Distribution of market cap
fig = go.Figure()
fig.add_trace(
    go.Histogram(x = df['profit_margins'].apply(lambda x : float(x) if not pd.isna(x) else None))
)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')
fig.update_xaxes(title = f'Profit margin of company in sector "{SECTOR}" and industry "{INDUSTRY}"')
fig.update_layout(
    width = 1000,
    height = 500,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 20)
)
fig.show()

# %%
# Distribution of market cap
fig = go.Figure()
fig.add_trace(
    go.Histogram(x = df['earning_per_share'].apply(lambda x : float(x) if not pd.isna(x) else None))
)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')
fig.update_xaxes(title = f'EPS of company in sector "{SECTOR}" and industry "{INDUSTRY}"')
fig.update_layout(
    width = 1000,
    height = 500,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 20)
)
fig.show()

# %%
# Distribution of market cap
fig = go.Figure()
fig.add_trace(
    go.Histogram(x = df['evebitda'].apply(lambda x : float(x) if not pd.isna(x) else None))
)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')
fig.update_xaxes(title = f'EV/EBITDA of company in sector "{SECTOR}" and industry "{INDUSTRY}"')
fig.update_layout(
    width = 1000,
    height = 500,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 20)
)
fig.show()

# %%
# Distribution of market cap
fig = go.Figure()
fig.add_trace(
    go.Histogram(x = df['peg_ratio'].apply(lambda x : float(x) if not pd.isna(x) else None))
)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')
fig.update_xaxes(title = f'PEG ratio of company in sector "{SECTOR}" and industry "{INDUSTRY}"')
fig.update_layout(
    width = 1000,
    height = 500,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 20)
)
fig.show()

# %%
# Distribution of market cap
fig = go.Figure()
fig.add_trace(
    go.Histogram(x = df['de_ratio'].apply(lambda x : float(x) if not pd.isna(x) else None))
)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')
fig.update_xaxes(title = f'DE ratio of company in sector "{SECTOR}" and industry "{INDUSTRY}"')
fig.update_layout(
    width = 1000,
    height = 500,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 20)
)
fig.show()

# %%
# Screen companies by metrics
query = f"""
    SELECT
        company_name,
        stock_code,
        fundamental->>'industry' AS industry,
        
        fundamental->>'marketCap' AS market_cap,
        fundamental->>'priceToBook' AS pb_ratio,
        fundamental->>'profitMargins' AS profit_margins,
        fundamental->>'trailingEps' AS earning_per_share,
        fundamental->>'enterpriseToEbitda' AS evebitda,
        fundamental->>'trailingPegRatio' AS peg_ratio,
        fundamental->>'debtToEquity' AS de_ratio
    FROM stock_info
    WHERE
        fundamental->>'sector' = '{SECTOR}'
        AND
        fundamental->>'industry' = '{INDUSTRY}'
        
"""
screen = pd.read_sql_query(query, engine).set_index('stock_code')
screen
# Out:
#                                    company_name       industry  market_cap  \
# stock_code
# AAC         Australian Agricultural Company Ltd  Farm Products   849901440
# DBF                  Duxton Broadacre Farms Ltd  Farm Products    57620220
# CSS                      Clean Seas Seafood Ltd  Farm Products    18319482
# FRM                        Farm Pride Foods Ltd  Farm Products    39581280
# MCA                    Murray Cod Australia Ltd  Farm Products    14279491
# NZK              New Zealand King Salmon Co Ltd  Farm Products   111835904
# RFA                    Rare Foods Australia Ltd  Farm Products     6255609
# SVL                            Silver Mines Ltd  Farm Products   147721360
# AAP                    Australian Agri Projects  Farm Products    15481368
# E33                                 East 33 Ltd  Farm Products    17093098
# ELD                                  Elders Ltd  Farm Products  1375124224
# ...

# %%
the_company = screen.loc['NZK']
the_company
# Out:
# company_name         New Zealand King Salmon Co Ltd
# industry                              Farm Products
# market_cap                                111835904
# pb_ratio                                  0.5694444
# profit_margins                          0.120790005
# earning_per_share                              0.04
# evebitda                                      2.626
# peg_ratio                                      None
# de_ratio                                      4.918
# Name: NZK, dtype: object

# %%
# Rerun the histogram, but add the company in it
fig = make_subplots(rows = 4, cols = 2)
metrics = ['market_cap', 'pb_ratio', 'profit_margins', 'earning_per_share', 'evebitda', 'peg_ratio', 'de_ratio']

for i,metric in enumerate(metrics):
    fig.add_trace(
        go.Histogram(
            x = df[metric].apply(lambda x : float(x) if not pd.isna(x) else None), 
            marker = dict(color = 'blue'),
            showlegend = False
        ),
        row = (i // 2) + 1, col = (i % 2) + 1
    )
    fig.update_xaxes(title = metric, row = (i // 2) + 1, col = (i % 2) + 1)
fig.update_yaxes(showgrid = True, gridcolor = 'gray', title = 'Number of company')

fig.update_layout(
    width = 1000,
    height = 1000,
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font = dict(family = 'Lato', size = 18)
)
fig_full = fig.full_figure_for_development()
for i,metric in enumerate(metrics):
    y_range = fig_full['layout'][f'yaxis{i + 1 if i > 0 else ""}']['range']
    if the_company[metric] is not None:
        fig.add_shape(
            type="line",
            x0 = the_company[metric], x1 = the_company[metric],  # X-position for the vertical line
            y0 = 0, y1 = y_range[1],      # Scaled Y-position (relative to subplot)
            line=dict(color="red", width=2),
            row = (i // 2) + 1, col = (i % 2) + 1
        )
fig.show()
# Out:
# c:\Users\khoan\miniconda3\envs\stock\lib\site-packages\plotly\io\_kaleido.py:338: UserWarning:
#
# full_figure_for_development is not recommended or necessary for production use in most circumstances.
# To suppress this warning, set warn=False

# %%
# Repeat the analysis but within the sector now
# Out:
# c:\Users\khoan\miniconda3\envs\stock\lib\site-packages\plotly\io\_kaleido.py:338: UserWarning:
#
# full_figure_for_development is not recommended or necessary for production use in most circumstances.
# To suppress this warning, set warn=False
