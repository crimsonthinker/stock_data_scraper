# %%
from analysis.modules.indicators import momentum_indicators

# %%
momentum_indicators('ACB')
# Out:
# Query data
# /home/khoa/miniconda3/envs/investment/lib/python3.9/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                   RSI RSI_trend        ADX   MINUS_DI    PLUS_DI ADX_trend
# date
# 2021-02-04        NaN      wait        NaN        NaN        NaN      wait
# 2021-02-05        NaN      wait        NaN        NaN        NaN      wait
# 2021-02-08        NaN      wait        NaN        NaN        NaN      wait
# 2021-02-09        NaN      wait        NaN        NaN        NaN      wait
# 2021-02-17        NaN      wait        NaN        NaN        NaN      wait
# ...               ...       ...        ...        ...        ...       ...
# ...
