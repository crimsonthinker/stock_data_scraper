# %%
# %load_ext autoreload
# %autoreload 2

# %%
from analysis.modules.fibonacci_retracement import fibonacci_retracement_strategy

# %%
df = fibonacci_retracement_strategy(stock_code = 'ACB',  day_interval = 60)
